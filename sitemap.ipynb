# %%
# %load_ext autoreload
# %autoreload 2
from product_validation import ProductValidation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ***GarphelShop Store*** ![garphelshop](images/logo.jpeg)

# %% [markdown]
# * Store Name: GarphelShop
#
# * owners: Naiany, Raphael, Gabriel
#
# * url: https://garphelshop.com
#
# * e-mails:
#
# | addr                         | purpose       |
# |------------------------------|---------------|
# | support@garphel.com          | Support       |
# | garphelshop@gmail.com        | Social Medias |
#
# * social medias:
#
# <a href="https://instagram.com/garphelshop" target="_blank">
# <img src="images/instagram.svg" alt="Instagram" width="50" height="50">
# </a>
# <a href="https://facebook.com/garphelshop" target="_blank">
# <img src="images/facebook.png" alt="Instagram" width="50" height="50">
# </a>
# <a href="https://tiktok.com/@garphel.shop" target="_blank">
# <img src="images/tiktok.svg" alt="Instagram" width="50" height="50">
# </a>
# <a href="https://pinterest.com/garphelshop target=" target="_blank">
# <img src="images/pinterest.png" alt="Instagram" width="50" height="50">
# </a>

# %% [markdown]
# ## Goal

# %% [markdown]
# Our mission is simple: to offer practical products that make everyday life easier.
#
# We carefully select items designed to help solve real daily problems — whether at home, at work, or on the go. Every product we offer has a purpose: to bring convenience, efficiency, and value to our customers’ lives.
#
# Beyond business, we believe in responsibility and impact. A portion of our revenue is dedicated to supporting charitable initiatives and helping people in need. When you shop with us, you’re not just buying a product — you’re contributing to positive change.
#
# We are committed to quality, honesty, and making a difference — one purchase at a time.

# %% [markdown]
# Market (USD bilions)
# <pre>
# China  | █████████████████████████████  3450
# USA    | ████████████████               1380
# UK     | ████                           195
# Japan  | ███                            169
# Korea  | ███                            147
# Germany| ███                            140
# India  | ███                            136
# Indon. | ██                             94
# France | ██                             92
# Canada | ██                             88
# </pre>

# %% [markdown]
# | **Position** | **Countries**            | **Market (USD)** | 📱 **Devices most used**          |
# | ----------- | ------------------- | -------------------------- | -------------------------------------- |
# | 1           | 🇨🇳 China          | ~$3,45 tri                 | 📱 Smartphone                          |
# | 2           | 🇺🇸 United States  | ~$1,38 tri                 | 📱 Smartphone / 💻 Desktop             |
# | 3           | 🇬🇧 United Kingdom | ~$195 bi                   | 📱 Smartphone                          |
# | 4           | 🇯🇵 Japan          | ~$169 bi                   | 📱 Smartphone                          |
# | 5           | 🇰🇷 South Korea    | ~$147 bi                   | 📱 Smartphone                          |
# | 6           | 🇩🇪 Germany        | ~$140 bi                   | 💻 Desktop (smartphone increasing) |
# | 7           | 🇮🇳 India          | ~$136 bi                   | 📱 Smartphone                          |
# | 8           | 🇮🇩 Indonesia      | ~$94 bi                    | 📱 Smartphone                          |
# | 9           | 🇫🇷 France         | ~$92 bi                    | 📱 Smartphone                          |
# | 10          | 🇨🇦 Canada         | ~$88 bi                    | 📱 Smartphone                          |

# %% [markdown]
# ## Suppliers

# %% [markdown]
# ### Factory level

# %% [markdown]
# * Thomasnet
#
# * 1688.com
#
# * Indiamart
#
# * made in china
#
# * DHGate
#
# * Global Sources
#
# * Kompass

# %% [markdown]
# ### Dropshipping suppliers network

# %% [markdown]
# * Aliexpress
#
# * Alibaba
#
# * CJ Dropshipping
#
# * Etsy
#
# * Walmart
#
# * Ebay
#
# * Reddit

# %% [markdown]
# ## Products

# %%
prdc = ProductValidation()
prod1 = prdc.genRawProduct(
    'cutting board',
    "https://mu-em-b.en.made-in-china.com/product/vpqYzTSxgoki/China-Eco-Friendly-Bamboo-Cutting-Board-with-Integrated-Drawer-Tray-Design.html?pv_id=1jhc0445cbec&faw_id=1jhc04hukef3&bv_id=1jhc04hup13e&pbv_id=1jhc0427jbc3")
prod2 = prdc.genRawProduct(
    'portable stove',
    "https://meshinesports.en.made-in-china.com/product/DdlAUgcHgTfO/China-Burner-Gas-Hot-Sell-Outdoor-Road-Trip-Camping-Burner-Butane-Portable-Gas-Stove-with-Carrying-Case.html?pv_id=1jhcs2vdm88b&faw_id=1jhcs31dl1dd&bv_id=1jhcs3sdbea7&pbv_id=1jhcs2tc14d3")

# %% [markdown]
# ### Keywords

# %% [markdown]
# #### Kitchen

# %% [markdown]
# the kitchen, kitchen design, kitchen ideas, kitchen table, kitchen set, kitchen storage, modern kitchen, outdoor kitchen, modular kitchen, kitchen lights, kitchen furniture, kitchen utensils

# %% [markdown]
# ![Kitchen](keywords/kitchen/kitchen.png)
