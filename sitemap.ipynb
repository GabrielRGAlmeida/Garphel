# %%
# %load_ext autoreload
# %autoreload 2
from product_validation import ProductValidation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # ***GarphelShop Store*** ![garphelshop](images/logo.jpeg)

# %% [markdown]
# * Store Name: GarphelShop
#
# * owners: Raphael, Gabriel
#
# * url: https://garphelshop.com
#
# * e-mails:
#
# | addr                         | purpose       |
# |------------------------------|---------------|
# | support@garphel.com          | Support       |
# | garphelshop@gmail.com        | Social Medias |
#
# * social medias:
#
# <a href="https://instagram.com/garphelshop" target="_blank">
# <img src="images/instagram.svg" alt="Instagram" width="50" height="50">
# </a>
# <a href="https://facebook.com/garphelshop" target="_blank">
# <img src="images/facebook.png" alt="Instagram" width="50" height="50">
# </a>
# <a href="https://tiktok.com/@garphel.shop" target="_blank">
# <img src="images/tiktok.svg" alt="Instagram" width="50" height="50">
# </a>
# <a href="https://pinterest.com/garphelshop target=" target="_blank">
# <img src="images/pinterest.png" alt="Instagram" width="50" height="50">
# </a>

# %% [markdown]
# ### Job List

# %% [markdown]
# * Wordpress site design - 3–8% of project budget (not revenue)
#
# * UI / UX - 500–3,000 USD per project
#
# * Social Media Agent - 800–2,500 USD/month
#
# * Influencer - 10–30% commission per sale
#
# * Product search, validation - 3–8% of revenue from winning product
#
# * Supplier/Customer contact - Fixed salary 200 USD
#
# * Fullstack - 1,500–5,000 USD/month
#
# * Blog writer - 500–2,000 USD/month
#
# * SEO Agent - 1,000–3,000 USD/month
#
# * CRO (Conversion Rate Optimization) - 5–15% of increased revenue
#
# * Video Editing - 50–300 USD per video
#
# * Legal consultant - 1,500 USD/month
#
# * Data Analyst - 2,000 USD/month
#
# * Accountant - 1,000 USD/month
#
# * Logistic/Inventory Manager - 1,300 USD/month
#
# * Brand Strategist 1,000–10,000 USD depending level
#
# * Market Placer Manager - 5–12% of marketplace revenue
#
# * Initial Investor

# %% [markdown]
# ## Goal

# %% [markdown]
# Our mission is simple: to offer practical products that make everyday life easier.
#
# We carefully select items designed to help solve real daily problems — whether at home, at work, or on the go. Every product we offer has a purpose: to bring convenience, efficiency, and value to our customers’ lives.
#
# Beyond business, we believe in responsibility and impact. A portion of our revenue is dedicated to supporting charitable initiatives and helping people in need. When you shop with us, you’re not just buying a product — you’re contributing to positive change.
#
# We are committed to quality, honesty, and making a difference — one purchase at a time.

# %% [markdown]
# Market (USD bilions)
# <pre>
# China  | █████████████████████████████  3450
# USA    | ████████████████               1380
# UK     | ████                           195
# Japan  | ███                            169
# Korea  | ███                            147
# Germany| ███                            140
# India  | ███                            136
# Indon. | ██                             94
# France | ██                             92
# Canada | ██                             88
# </pre>

# %% [markdown]
# | **Position** | **Countries**            | **Market (USD)** | 📱 **Devices most used**          |
# | ----------- | ------------------- | -------------------------- | -------------------------------------- |
# | 1           | 🇨🇳 China          | ~$3,45 tri                 | 📱 Smartphone                          |
# | 2           | 🇺🇸 United States  | ~$1,38 tri                 | 📱 Smartphone / 💻 Desktop             |
# | 3           | 🇬🇧 United Kingdom | ~$195 bi                   | 📱 Smartphone                          |
# | 4           | 🇯🇵 Japan          | ~$169 bi                   | 📱 Smartphone                          |
# | 5           | 🇰🇷 South Korea    | ~$147 bi                   | 📱 Smartphone                          |
# | 6           | 🇩🇪 Germany        | ~$140 bi                   | 💻 Desktop (smartphone increasing) |
# | 7           | 🇮🇳 India          | ~$136 bi                   | 📱 Smartphone                          |
# | 8           | 🇮🇩 Indonesia      | ~$94 bi                    | 📱 Smartphone                          |
# | 9           | 🇫🇷 France         | ~$92 bi                    | 📱 Smartphone                          |
# | 10          | 🇨🇦 Canada         | ~$88 bi                    | 📱 Smartphone                          |

# %% [markdown]
# ## Suppliers

# %% [markdown]
# ### Factory level

# %% [markdown]
# * Thomasnet
#
# * 1688.com
#
# * Indiamart
#
# * made in china
#
# * DHGate
#
# * Global Sources
#
# * Kompass

# %% [markdown]
# ### Dropshipping suppliers network

# %% [markdown]
# * Aliexpress
#
# * Alibaba
#
# * CJ Dropshipping
#
# * Etsy
#
# * Walmart
#
# * Ebay
#
# * Reddit

# %% [markdown]
# ## Products

# %%
prdc = ProductValidation()
prod1 = prdc.genRawProduct(
    'cutting board',
    "https://mu-em-b.en.made-in-china.com/product/vpqYzTSxgoki/China-Eco-Friendly-Bamboo-Cutting-Board-with-Integrated-Drawer-Tray-Design.html?pv_id=1jhc0445cbec&faw_id=1jhc04hukef3&bv_id=1jhc04hup13e&pbv_id=1jhc0427jbc3")
prod2 = prdc.genRawProduct(
    'portable stove',
    "https://meshinesports.en.made-in-china.com/product/DdlAUgcHgTfO/China-Burner-Gas-Hot-Sell-Outdoor-Road-Trip-Camping-Burner-Butane-Portable-Gas-Stove-with-Carrying-Case.html?pv_id=1jhcs2vdm88b&faw_id=1jhcs31dl1dd&bv_id=1jhcs3sdbea7&pbv_id=1jhcs2tc14d3")

# %% [markdown]
# ### Keywords

# %% [markdown]
# #### Kitchen

# %% [markdown]
# the kitchen, kitchen design, kitchen ideas, kitchen table, kitchen set, kitchen storage, modern kitchen, outdoor kitchen, modular kitchen, kitchen lights, kitchen furniture, kitchen utensils

# %% [markdown]
# ![Kitchen](keywords/kitchen/kitchen.png)

# %% [markdown]
# When you buy products on Alibaba to **legally import into Brazil**, there is no single “universal certificate” that is enough — the requirements depend on **the type of product** you intend to import.
#
# However, there are **common and mandatory documents and certifications** required both for export from the supplier and for customs clearance in Brazil.
#
# ---
#
# # 📌 **1. Basic Documents the Supplier Must Provide**
#
# These are essential regardless of product type:
#
# ✅ **Commercial Invoice** – Detailed international invoice including correct product description, values, weight, manufacturer information, and HS/NCM code.
#
# ✅ **Packing List** – Detailed packing document showing quantity, weight, number of cartons, and dimensions.
#
# ✅ **Bill of Lading (B/L) or Air Waybill (AWB)** – Transport document (sea or air freight).
#
# ✅ **Certificate of Origin** – Certifies the country of origin of the goods (may reduce taxes under trade agreements).
#
# 👉 The first three documents are mandatory for any formal importation into Brazil. The Certificate of Origin may assist with tariff calculation and product classification.
#
# ---
#
# # 📌 **2. Mandatory Certifications and Approvals (Depending on the Product)**
#
# ## 🔹 INMETRO
#
# Required for products such as:
#
# * Electronics and electrical devices
# * Toys
# * Power tools
# * Equipment involving electrical consumption or safety risks
#
# This is a **Brazilian certification**. The supplier may assist by providing international test reports or documentation, but Brazilian certification is still required for regulated products.
#
# ---
#
# ## 🔹 ANVISA
#
# Required for health-related products such as:
#
# * Cosmetics
# * Medicines
# * Dietary supplements
# * Medical devices
#
# These products typically require registration or prior authorization from the Brazilian regulatory agency before commercialization.
#
# ---
#
# ## 🔹 MAPA
#
# For products of animal or plant origin (food, seeds, plants, derivatives), requirements may include:
#
# * Phytosanitary certificate
# * Proof of being free from pests and diseases prior to shipment
#
# ---
#
# # 📌 **3. Useful International Certifications**
#
# *(They do NOT replace Brazilian approvals, but they help.)*
#
# These certificates do not automatically authorize import into Brazil, but they:
#
# * Demonstrate quality standards
# * Facilitate homologation processes
# * Increase credibility
#
# ✔ **ISO (e.g., ISO 9001)** – Manufacturer quality management system
# ✔ **CE Marking** – Compliance with European Union standards
# ✔ **RoHS / REACH** – Restriction of hazardous substances (common for electronics and toys)
# ✔ **HACCP / GMP** – Important for food and cosmetics, demonstrating quality control systems
#
# ➡ Having these certifications can speed up Brazilian homologation processes when required — but they **do not replace INMETRO, ANVISA, or MAPA requirements** when those are mandatory.
#
# ---
#
# # 📌 **4. What the Brazilian Importing Company Must Have**
#
# Even if the supplier provides all required documents, **your company in Brazil must be legally enabled to import:**
#
# 📌 **RADAR / SISCOMEX registration** – Authorization to operate in foreign trade
# 📌 **Fiscal Classification (NCM)** – Code that determines tax rules and regulatory requirements
# 📌 **Import License (LI)** – Some product categories require prior licensing before shipment or clearance
#
# ---
#
# # 📌 **Practical Summary**
#
# | Product Type                           | Most Important Certification / Documents                                                |
# | -------------------------------------- | --------------------------------------------------------------------------------------- |
# | Electronics & electrical risk products | **INMETRO + Commercial Invoice + Packing List + Transport Docs**                        |
# | Cosmetics / health products            | **ANVISA + Commercial Invoice + Packing List + Transport Docs**                         |
# | Food / plants                          | **MAPA Phytosanitary Certificate + Commercial Invoice + Packing List + Transport Docs** |
# | General products (no specific risk)    | **Commercial Invoice + Packing List + B/L or AWB + Certificate of Origin**              |
#
# ---
#
# ✅ **Important:**
# The Alibaba supplier does not need a “special export certificate” to ship products. However, the products must comply with Brazilian regulations before entering the country — and you, as the importer, are responsible for ensuring compliance and that all documentation is correct before shipment to avoid customs detention.
